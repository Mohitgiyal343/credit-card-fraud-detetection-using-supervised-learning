# %% [markdown]
# # 03. Model Training
#
# This notebook trains multiple machine learning classifiers to predict credit card fraud. Objectives:
# - Train baseline models (Logistic Regression, Random Forest, etc.).
# - Tune hyperparameters using Cross-Validation.
# - Save the best performing model using `joblib` or `pickle`.

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
import joblib

# %% [markdown]
# ## 1. Train Classifier

# %%
# clf = RandomForestClassifier(n_estimators=100, random_state=42, n_jobs=-1)
# clf.fit(X_train, y_train)

# %% [markdown]
# ## 2. Save Best Model

# %%
# joblib.dump(clf, '../models/best_model.pkl')
